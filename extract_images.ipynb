# %%
pip install python-gdcm
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/24.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.9 MB ? eta -:--:--
# ...

# %%
#import libraries 
import pydicom
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
#resize the image

# img = np.transpose(img, (1, 2, 0 ))
dcm =  pydicom.dcmread(rf"C:\Users\Wahaj Sajid\Desktop\Research\MIDRC\Female Black, Age below 75 Covid19 data\1.2.826.0.1.3680043.10.474.419639.103920479813683567842234214555.dcm")
img =  dcm.pixel_array#access the pixel data

# If the image is not 2D, try transposing (common for segmentation masks)
if img.ndim == 3 and img.shape[0] <= 4:  # Likely (channels, rows, columns)
    img = np.transpose(img, (1, 2, 0))

# If the image is still not displayable, try displaying a single channel
if img.ndim == 3:
    img = img[..., 0]  # Take first channel

# Optional: Apply scaling if needed
if hasattr(dcm, 'RescaleSlope') and hasattr(dcm, 'RescaleIntercept'):
    img = img * dcm.RescaleSlope + dcm.RescaleIntercept

# Display the image
plt.imshow(img, cmap=plt.cm.gray)
plt.axis('off')
plt.show()

# %%
dcm =  pydicom.dcmread(rf"C:\Users\Wahaj Sajid\Desktop\Research\Research Project\MIDRC\downloads\302028-000212\1.2.826.0.1.3680043.10.474.302028.495660\1.2.826.0.1.3680043.10.474.302028.496306\1.2.826.0.1.3680043.10.474.302028.496383.dcm")
img =  dcm.pixel_array

#display the image
plt.imshow(img, cmap = plt.cm.gray)
plt.show()
